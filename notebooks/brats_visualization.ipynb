# %%
from pathlib import Path
import matplotlib.pyplot as plt
import nibabel as nib

# %%
brats2018_path = Path(
    "/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1"
)
list(brats2018_path.glob("*"))
# Out:
# [PosixPath('/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1_t2.nii'),
#  PosixPath('/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1_seg.nii'),
#  PosixPath('/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1_flair.nii'),
#  PosixPath('/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1_t1ce.nii'),
#  PosixPath('/home/stud/strasser/archive/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1_t1.nii')]

# %%
LAYER = 95

# %%
print("T1: ")
p = next(brats2018_path.glob("*t1.nii"))
mri_np = nib.load(p).get_fdata()
plt.imshow(
    mri_np[:, :, LAYER], cmap="gray"
)  # Zeige eine einzelne Schicht des Bildes an
plt.axis("off")  # Deaktiviere die Achsen
plt.show()
# Out:
# T1:

# %%
print("T1ce: ")
p = next(brats2018_path.glob("*t1ce.nii"))
mri_np = nib.load(p).get_fdata()
plt.imshow(
    mri_np[:, :, LAYER], cmap="gray"
)  # Zeige eine einzelne Schicht des Bildes an
plt.axis("off")  # Deaktiviere die Achsen
plt.show()
# Out:
# T1ce:

# %%
print("FLAIR: ")
p = next(brats2018_path.glob("*flair.nii"))
mri_np = nib.load(p).get_fdata()
plt.imshow(
    mri_np[:, :, LAYER], cmap="gray"
)  # Zeige eine einzelne Schicht des Bildes an
plt.axis("off")  # Deaktiviere die Achsen
plt.show()
# Out:
# FLAIR:

# %%
print("T2: ")
p = next(brats2018_path.glob("*t2.nii"))
mri_np = nib.load(p).get_fdata()
plt.imshow(
    mri_np[:, :, LAYER], cmap="gray"
)  # Zeige eine einzelne Schicht des Bildes an
plt.axis("off")  # Deaktiviere die Achsen
plt.show()
# Out:
# T2:

# %%
print("Segmentation: ")
p = next(brats2018_path.glob("*seg.nii"))
mri_np = nib.load(p).get_fdata()
plt.imshow(
    mri_np[:, :, LAYER], cmap="gray"
)  # Zeige eine einzelne Schicht des Bildes an
plt.axis("off")  # Deaktiviere die Achsen
plt.show()
# Out:
# Segmentation:
